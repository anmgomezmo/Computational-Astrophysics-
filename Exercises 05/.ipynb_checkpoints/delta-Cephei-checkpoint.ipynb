# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('delta_cephei.csv')
data.head()
# Out:
#    Year Month  Day  Magnitude
# 0  1906  June   30       2.34
# 1  1906  July    1       2.22
# 2  1906  July    3       2.84
# 3  1906  July    8       2.93
# 4  1906  July   11       2.30

# %%
month = np.array(data['Month'])
month
# Out:
# array(['June', 'July', 'July', 'July', 'July', 'July', 'July', 'July',
#        'July', 'July', 'July', 'July', 'July', 'July', 'July', 'July',
#        'August', 'August', 'August', 'August', 'August', 'August',
#        'August', 'August', 'August', 'August', 'August', 'August',
#        'August', 'August', 'August', 'August', 'August', 'August',
#        'September', 'September', 'September', 'September', 'September',
#        'September', 'September', 'October', 'October', 'October',
#        'November', 'November', 'November', 'November', 'November',
#        'December', 'January', 'February', 'February', 'February', 'June',
#        'July', 'July', 'July', 'July', 'August', 'August', 'August',
#        'August', 'August', 'August', 'August', 'August', 'August',
#        'August', 'August', 'September', 'September'], dtype=object)

# %%
print(type(month[0]))
print(type(data['Day']))
print(type(data['Year']))
# Out:
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
def month_string_to_number(string):
    m = {
        'jan': 1,
        'feb': 2,
        'mar': 3,
        'apr':4,
        'may':5,
        'jun':6,
        'jul':7,
        'aug':8,
        'sep':9,
        'oct':10,
        'nov':11,
        'dec':12
        }
    s = string.strip()[:3].lower()

    try:
        out = m[s]
        return out
    except:
        raise ValueError('Not a month')

# %%
l = len(month)
s = pd.Series(l)
for i in range(l):
    s[i] = month_string_to_number(month[i])
    
s
# Out:
# 0     6
# 1     7
# 2     7
# 3     7
# 4     7
#      ..
# 67    8
# 68    8
# 69    8
# 70    9
# 71    9
# Length: 72, dtype: int64

# %%
data['Month'] = s # too can be s.values
data
# Out:
#     Year  Month  Day  Magnitude
# 0   1906      6   30       2.34
# 1   1906      7    1       2.22
# 2   1906      7    3       2.84
# 3   1906      7    8       2.93
# 4   1906      7   11       2.30
# ..   ...    ...  ...        ...
# 67  1907      8   25       2.83
# 68  1907      8   29       2.18
# 69  1907      8   30       2.48
# 70  1907      9   10       2.76
# 71  1907      9   12       2.52
#
# [72 rows x 4 columns]

# %%
from datetime import datetime
day_of_year = datetime.now().timetuple().tm_yday
day_of_year
# Out:
# 22

# %%
def month_to_days(month):
    a = np.array([1,3,5,7,8,10,12])
    b = np.array([4,6,9,11])
    if np.any(month == a):
        aux = 31
    elif np.any(month == b):
        aux = 30
    else:
        aux = 28
    return aux

# %%
day = np.array(data['Day'])
month = np.array(data['Month'])
year = np.array(data['Year'])
print(month)
m = np.zeros(l)
for i in range(l):
    m[i] = month_to_days(month[i])
m
# Out:
# [ 6  7  7  7  7  7  7  7  7  7  7  7  7  7  7  7  8  8  8  8  8  8  8  8
#   8  8  8  8  8  8  8  8  8  8  9  9  9  9  9  9  9 10 10 10 11 11 11 11
#  11 12  1  2  2  2  6  7  7  7  7  8  8  8  8  8  8  8  8  8  8  8  9  9]
# array([30., 31., 31., 31., 31., 31., 31., 31., 31., 31., 31., 31., 31.,
#        31., 31., 31., 31., 31., 31., 31., 31., 31., 31., 31., 31., 31.,
#        31., 31., 31., 31., 31., 31., 31., 31., 30., 30., 30., 30., 30.,
#        30., 30., 31., 31., 31., 30., 30., 30., 30., 30., 31., 31., 28.,
#        28., 28., 30., 31., 31., 31., 31., 31., 31., 31., 31., 31., 31.,
#        31., 31., 31., 31., 31., 30., 30.])

# %%
date_array = np.zeros(l)
fmt = '%d.%m.%Y'
for i in range(1,l+1):
    day_str = ''.join(str(e) for e in day[i-1:i])
    month_str = ''.join(str(e) for e in month[i-1:i])
    year_str = ''.join(str(e) for e in year[i-1:i])
    date = day_str + '.' + month_str + '.' + year_str
    #print(date) 
    #print(type(date))
    dt = datetime.strptime(date, fmt)
    tt = dt.timetuple()
    if year_str == '1906':
        date_array[i-1] = tt.tm_yday
    else:
        date_array[i-1] = tt.tm_yday+365
date_array
# Out:
# array([181., 182., 184., 189., 192., 195., 197., 198., 199., 202., 204.,
#        205., 207., 208., 210., 211., 213., 214., 216., 221., 222., 223.,
#        224., 228., 232., 233., 234., 235., 236., 237., 239., 240., 241.,
#        242., 259., 260., 262., 263., 265., 266., 267., 277., 280., 294.,
#        308., 313., 319., 327., 328., 335., 370., 410., 415., 421., 532.,
#        551., 553., 558., 572., 582., 584., 586., 587., 589., 595., 600.,
#        601., 602., 606., 607., 618., 620.])

# %% [markdown]
# # Interpolations with the date as number day correspond to the year, begining at 0 as 01/01/1906

# %%
plt.figure(figsize=(10,7))
plt.scatter(date_array,data['Magnitude'])
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.show()

# %%
j = 10
plt.figure(figsize=(10,7))
plt.scatter(date_array[:j],data['Magnitude'][:j])
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.show()

# %%
import LagrangeInterpolation as lag 
import HermiteInterpolation as her

# %%
# Define an array of points of variable x and its values of f 
x = date_array
y = data['Magnitude']
N = len(x)

# %%
def linearInterpolation(x1, x2, f1, f2, x):
    p1 = f1 + ((f2-f1)/(x2-x1))*(x-x1)
    return p1

def quadraticInterpolation(x1, x2, x3, f1, f2, f3, x):
    p2 = (((x-x2)*(x-x3))/((x1-x2)*(x1-x3)))*f1 + (((x-x1)*(x-x3))/((x2-x1)*(x2-x3)))*f2 +\
         (((x-x1)*(x-x2))/((x3-x1)*(x3-x2)))*f3
    return p2

plt.figure(figsize=(10,7))
plt.scatter(x, y, color='black')

for i in range(N-1):
    x_interval = np.linspace(x[i],x[i+1],3) 
    # Note that the number 3 in thie above line indeicates the number of 
    # points interpolated in each interval !
    # (including the extreme points of the interval)
    y_interval = linearInterpolation(x[i], x[i+1], y[i], y[i+1], x_interval)
    plt.plot(x_interval, y_interval,'r')
    
for i in range(N-2):
    x_interval = np.linspace(x[i],x[i+1],6) # 6 interpolate points in each interval
    y_interval = quadraticInterpolation(x[i], x[i+1], x[i+2], y[i], y[i+1], y[i+2], x_interval)
    plt.plot(x_interval, y_interval,'g')
    
plt.title(r'Linear and Cuadratic Polynomial Piecewise Interpolation')
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.show()

# %%
# Interpolate the last points with a polynomial
n = 10
plt.figure(figsize=(10,7))
plt.scatter(x,y,label='Original function')

for i in range(N-n):
    xi = x[i:i+n+1]
    fi = y[i:i+n+1]
    x_interval = np.linspace(x[i],x[i+1],3*n)
    y_interval = lag.p(x_interval,xi,fi)
    plt.plot(x_interval, y_interval,'r',label='Polynomial Interpolated')

plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-d9e47370bdc5> in <module>
#       8     fi = y[i:i+n+1]
#       9     x_interval = np.linspace(x[i],x[i+1],3*n)
# ---> 10     y_interval = lag.p(x_interval,xi,fi)
#      11     plt.plot(x_interval, y_interval,'r',label='Polynomial Interpolated')
#      12
#
# ~/Documents/github/Computational-Astrophysics-/Exercises 05/LagrangeInterpolation.py in p(x, xi, fi)
# ...

# %%
def Derivative(x, f):
    '''
    ------------------------------------------
    Derivative(x, f)
    ------------------------------------------
    This function returns the numerical 
    derivative of a discretely-sample function 
    using one-side derivatives in the extreme 
    points of the interval and second order 
    accurate derivative in the middle points.
    The data points may be evenly or unevenly
    spaced.
    ------------------------------------------
    '''
    # Number of points
    N = len(x)
    dfdx = np.zeros([N, 2])
    dfdx[:,0] = x
    
    # Derivative at the extreme points
    dfdx[0,1] = (f[1] - f[0])/(x[1] - x[0])
    dfdx[N-1,1] = (f[N-1] - f[N-2])/(x[N-1] - x[N-2])
    
    #Derivative at the middle points
    for i in range(1,N-1):
        h1 = x[i] - x[i-1]
        h2 = x[i+1] - x[i]
        dfdx[i,1] = h1*f[i+1]/(h2*(h1+h2)) - (h1-h2)*f[i]/(h1*h2) - h2*f[i-1]/(h1*(h1+h2))
    
    return dfdx

# %%
# Calling the derivative function and chosing only the second column
dfdx = Derivative(x,y)[:,1]

plt.figure(figsize=(10,7))
plt.title(f'Cubic Hermite Polynomial Piecewise Interpolation')
plt.scatter(x, y, color='black')

# Piecewise Hermite Interpolation Loop
for i in range(N-1):
    xi = x[i:i+2]
    fi = y[i:i+2]
    dfidx = dfdx[i:i+2]
    x_interval = np.linspace(x[i],x[i+1],4)
    y_interval = her.H3(x_interval, xi, fi, dfidx)
    plt.plot(x_interval, y_interval,'r')

plt.xlabel('Time [days]')
plt.ylabel('Apparent Magnitude')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-8526afb8e09c> in <module>
#      12     dfidx = dfdx[i:i+2]
#      13     x_interval = np.linspace(x[i],x[i+1],4)
# ---> 14     y_interval = her.H3(x_interval, xi, fi, dfidx)
#      15     plt.plot(x_interval, y_interval,'r')
#      16
#
# ~/Documents/github/Computational-Astrophysics-/Exercises 05/HermiteInterpolation.py in H3(x, xi, fi, dfidx)
# ...

# %%
from scipy import interpolate
s = interpolate.InterpolatedUnivariateSpline(x,y)
xnew = np.linspace(180,625,1000)
ynew = s(xnew)
plt.figure(figsize=(10,7))
plt.title(f'Split Interpolation of Scipy library')
plt.scatter(x, y, color='black')
plt.plot(xnew, ynew,'r')
plt.xlabel('Time [days]')
plt.ylabel('Apparent Magnitude')
plt.show()

# %% [markdown]
# # Interpolations with the date as number of days of observations, begining at 0 as 30/06/1906

# %%
j = 10
plt.figure(figsize=(10,7))
plt.plot(data['Magnitude'][:j],'.k')
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.show()

# %%
# Define an array of points of variable x and its values of f 
l = 10 
x = list(range(0,l))
y = data['Magnitude'][:l]
N = len(x)

# %%
plt.figure(figsize=(10,7))
plt.scatter(x, y, color='black')

for i in range(N-1):
    x_interval = np.linspace(x[i],x[i+1],3) 
    # Note that the number 3 in thie above line indeicates the number of 
    # points interpolated in each interval !
    # (including the extreme points of the interval)
    y_interval = linearInterpolation(x[i], x[i+1], y[i], y[i+1], x_interval)
    plt.plot(x_interval, y_interval,'r')
    
for i in range(N-2):
    x_interval = np.linspace(x[i],x[i+1],6) # 6 interpolate points in each interval
    y_interval = quadraticInterpolation(x[i], x[i+1], x[i+2], y[i], y[i+1], y[i+2], x_interval)
    plt.plot(x_interval, y_interval,'g')
    
plt.title(r'Linear and Cuadratic Polynomial Piecewise Interpolation')
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.show()

# %%
# Interpolate the last points with a polynomial
n = 4
plt.figure(figsize=(10,7))
plt.scatter(x,y,label='Original function')

for i in range(N-n):
    xi = x[i:i+n+1]
    fi = y[i:i+n+1]
    x_interval = np.linspace(x[i],x[i+1],3*n)
    y_interval = lag.p(x_interval,xi,fi)
    plt.plot(x_interval, y_interval,'r',label='Polynomial Interpolated')

plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-0114b50a8b65> in <module>
#       8     fi = y[i:i+n+1]
#       9     x_interval = np.linspace(x[i],x[i+1],3*n)
# ---> 10     y_interval = lag.p(x_interval,xi,fi)
#      11     plt.plot(x_interval, y_interval,'r',label='Polynomial Interpolated')
#      12
#
# ~/Documents/github/Computational-Astrophysics-/Exercises 05/LagrangeInterpolation.py in p(x, xi, fi)
# ...

# %%
# Calling the derivative function and chosing only the second column
dfdx = Derivative(x,y)[:,1]

plt.figure(figsize=(10,7))
plt.title(f'Cubic Hermite Polynomial Piecewise Interpolation')
plt.scatter(x, y, color='black')

# Piecewise Hermite Interpolation Loop
for i in range(N-1):
    xi = x[i:i+2]
    fi = y[i:i+2]
    dfidx = dfdx[i:i+2]
    x_interval = np.linspace(x[i],x[i+1],4)
    y_interval = her.H3(x_interval, xi, fi, dfidx)
    plt.plot(x_interval, y_interval,'r')

plt.xlabel('Time [days]')
plt.ylabel('Apparent Magnitude')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-8526afb8e09c> in <module>
#      12     dfidx = dfdx[i:i+2]
#      13     x_interval = np.linspace(x[i],x[i+1],4)
# ---> 14     y_interval = her.H3(x_interval, xi, fi, dfidx)
#      15     plt.plot(x_interval, y_interval,'r')
#      16
#
# ~/Documents/github/Computational-Astrophysics-/Exercises 05/HermiteInterpolation.py in H3(x, xi, fi, dfidx)
# ...

# %%
s = interpolate.InterpolatedUnivariateSpline(x,y)
xnew = np.linspace(0,l-1,100)
ynew = s(xnew)
plt.figure(figsize=(10,7))
plt.title(f'Split Interpolation of Scipy library')
plt.scatter(x, y, color='black')
plt.plot(xnew, ynew,'r')
plt.xlabel('Time [days]')
plt.ylabel('Apparent Magnitude')
plt.show()
